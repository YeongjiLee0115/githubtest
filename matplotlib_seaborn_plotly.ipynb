# %% [markdown]
# <a href="https://colab.research.google.com/github/YeongjiLee0115/githubtest/blob/main/matplotlib_seaborn_plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
from plotly import express as px

# %%
import numpy as np

# %%
diamonds = sns.load_dataset('diamonds')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#the most commonly used : matplotlib.pyplot
plt.plot(diamonds['x'], diamonds['y'])

# %%
plt.plot(diamonds['x'])

# %%
plt.plot(diamonds['x'], 'ro', color = 'darkgreen') #make it black #this is called format string #can do hax codes and add pound sign
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
#adobe illustrator, make legend, hue shifting or auto color you can change the colors from there

fig = plt.figure(figsize = (4, 5))

colors = { 'condition 1' : '#FF5733',
          'condition 2' : '#A44E3C',
          'condition 3' : '#599194',
          'condition 4' : '#3C9FA4',
          'condition 5' : '#1A4648'}
for i in range(5):
  plt.plot(np.cumsum(np.random.randn(1000)), color = colors[f'condition {i+1}'], label = f'condition {i+1}')
plt.legend()
plt.xlabel('xlabel', fontsize=14)
plt.xlim([0,500])
plt.title('title')

sns.despine(top=True, right=True) #remove the boarder of the box

fig.savefig('recording.pdf', bbox_inches = 'tight')
# Out:
# <ipython-input-26-76f537970abd>:1: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(diamonds['x'], 'ro', color = 'darkgreen') #make it black #this is called format string #can do hax codes and add pound sign

# %%
fig , ax = plt.subplots(figsize = (15, 2.5), nrows=1, ncols=5, sharex=True, sharey=True) #five you figure and axis handle 
#sharex : set all sets equals the same axis

colors = { 'condition 1' : '#FF5733',
          'condition 2' : '#A44E3C',
          'condition 3' : '#599194',
          'condition 4' : '#3C9FA4',
          'condition 5' : '#1A4648'}
for i in range(5):
  plt.axes(ax[i]) #the current ax you're drawing
  plt.plot(np.cumsum(np.random.randn(1000)), color = colors[f'condition {i+1}'], label = f'condition {i+1}')
  plt.title(f'condition {i+1}')

plt.legend()
plt.xlabel('xlabel', fontsize=14)
plt.xlim([0,500])
plt.tight_layout() # making it tight the spacing between the plots


sns.despine(top=True, right=True) #remove the boarder of the box

fig.savefig('recording.pdf', bbox_inches = 'tight')

# %%
# %matplotlib notebook #interactive notebook mode
# Out:
# UsageError: unrecognized arguments: #interactive notebook mode

# %%
# %matplotlib inline

# %%
t = 1000
x = np.cumsum(np.random.rand(t))
y = np.cumsum(np.random.rand(t))
z = np.cumsum(np.random.rand(t))

plt.plot(x, y, z)
plt.show()

# %%
#seaborn work with tidy data
#it's based on matplotlib

sns.scatterplot(data=diamonds, x = 'price', y = 'carat', hue='color')
plt.show()

# %%
penguins= sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.scatterplot(data=penguins, x = 'body_mass_g', y= 'bill_length_mm', hue='species', style = 'island')
sns.despine(top=True, right=True)
plt.xlabel('Body mass (g)', fontsize = 14)
plt.ylabel('Bill length (mm)', fontsize = 14) #you can use matplot things to custom label

#you can create your continuous color map 
#sns.light_palette("seagreen", as_map=True) #from white to the source color you defined.
# Out:
# Text(0, 0.5, 'Bill length (mm)')

# %%
#This is Plotly, slightly different syntax but almost the same as sns
#great for interacting with data
#good for exploration of data
px.scatter(penguins, x = 'body_mass_g', y= 'bill_length_mm', color='species', facet_col = 'island')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#This is Plotly, slightly different syntax but almost the same as sns
#great for interacting with data
#good for exploration of data
px.scatter(penguins, x = 'body_mass_g', y= 'bill_length_mm', color='species', facet_row = 'island', facet_col = 'sex', hover_name = 'bill_depth_mm')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#animation is good for time_related variable
px.scatter(diamonds.head(1000), x = 'price', y='carat', color='cut', animation_frame='clarity')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#make use of seaborn example codes
#https://seaborn.pydata.org/examples/index.html
#bar plots are automaticaly put error bars 95% CI

import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker",
               split=True, inner="quart", linewidth=1,
               palette={"Yes": "b", "No": ".85"})
sns.despine(left=True)

# %%
N = 1000
x = np.random.randn(N)
y = x+ 1.2 * np.random.randn(N)
plt.plot(x, y, 'ko')

# %%
import pandas as pd
df = pd.DataFrame({'x': x, 'y': y})
df
# Out:
#             x         y
# 0    1.351678 -1.240086
# 1   -2.349347 -2.161067
# 2   -1.077687 -2.645093
# 3   -1.143383 -2.657521
# 4   -0.790111 -0.020707
# ..        ...       ...
# 995  0.452221  1.069943
# 996 -0.841663 -1.247219
# 997  0.291856  0.000093
# 998 -1.329253 -1.149945
# 999 -0.230482  0.163368
#
# [1000 rows x 2 columns]

# %%
sns.lmplot(df, x='x', y='y', scatter_kws={'alpha': 0.3})
sns.despine(top=True, right=True)
#the error ribon is wrapping the regression line

# %%
sns.regplot(df, x='x', y='y', scatter_kws={'alpha': 0.3})
sns.despine(top=True, right=True)
#it doesn't have a way to get out the coefficient value from the regression it plotted
# we need scipy, separate library to get the value of coefficient

# %%
from scipy.stats import linregress
result = linregress(x,y)
print(result)
result.slope
# Out:
# LinregressResult(slope=0.9924300821395557, intercept=-0.05937147401987071, rvalue=0.628932978009644, pvalue=3.158146058311167e-111, stderr=0.03883363721479411, intercept_stderr=0.038314092439488065)
# 0.9924300821395557

# %%
sns.regplot(df, x='x', y='y', scatter_kws={'alpha': 0.3})
sns.despine(top=True, right=True)
#it doesn't have a way to get out the coefficient value from the regression it plotted
# we need scipy, separate library to get the value of coefficient
slope = result.slope
intercept = result.intercept

reg_str = f'slope = {result.slope:0.3f}\nintercept = {result.intercept:0.3f}'
plt.text(0, 4, reg_str)
# Out:
# Text(0, 4, 'slope = 0.992\nintercept = -0.059')
